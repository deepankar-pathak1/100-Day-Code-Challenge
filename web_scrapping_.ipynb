# %% [markdown]
# <a href="https://colab.research.google.com/github/deepankar-pathak1/100-Day-Code-Challenge/blob/main/web_scrapping_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# !pip install bs4
# !pip install html5lib

# %%
import requests
from bs4 import BeautifulSoup
url = "https://latestinbollywood.com/"

# %%
r = requests.get(url)
htmlContent = r.content
# print(htmlContent)

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
# print(soup.prettify)

# %%
# step 3 HTML Tree
title = soup.title
# print(title) # get the title of HTML Page
# print(type(title))
# print(title.string)

# %%
# Type of objects
# 1. Tag
# 2. Navigable string 
# 3. BeautifulSoup
# 4. Comment 

# print(type(soup))

# %%
title = soup.title

# Get all the Para from corpus
# paras = soup.find_all('p')
# print(paras)

# anchors = soup.find_all('a')
# print(anchors)

# %%
print(soup.find('p')['class'])
# Out:
# ['site-description']

# %%
# we have to find all the class which have class site
print(soup.find_all("p", class_ = "post-form"))
# Out:
# []

# %%
# Text from data

print(soup.find('a').get_text())
# Out:
# Skip to content

# %%
all_links = set()
for link in anchors:
    all_links.add(link.get('href'))

print(all_links, end="/n")
# Out:
# {'https://latestinbollywood.com/entertainment/', 'https://latestinbollywood.com/tv/', '', '#', 'https://latestinbollywood.com/2021/02/', 'https://latestinbollywood.com/lifestyle/', 'https://latestinbollywood.com/movies/review/', 'https://wordpress.org/', 'https://latestinbollywood.com/', 'https://latestinbollywood.com/massive-fire-breaks-on-the-sets-of-prabhas-saif-ali-khans-adipurush/', 'https://latestinbollywood.com/vallamai-tharayo-star-srivatsav-chandrasekar-dies/', 'https://latestinbollywood.com/celebrity/', 'https://latestinbollywood.com/american-idol-2021-contestants-lists-top-20-names/#comment-4', 'https://latestinbollywood.com/author/adminmlb/', 'https://latestinbollywood.com/soundarya-sathyanarayana/#comment-2', '#tan-main-banner-latest-trending-popular-popular', 'https://latestinbollywood.com/web-series/', 'https://latestinbollywood.com/gandi-baat-actress-gehana-vasisth-arrested-for-shooting-uploading-obscene-videos/', 'https://latestinbollywood.com/page/36/', '#content', 
# ...

# %%
# Comment 
markup = "<p><!-- this is a comment --></p>"
soup2 = BeautifulSoup(markup)
print(type(soup2.p.string))
# Out:
# <class 'bs4.element.Comment'>

# %%
navbarid = soup.find(id = 'page')
# print(navbarid.contents)
for elm in navbarid.contents:
    # print(elm)
# Out:
# <a class="skip-link screen-reader-text" href="#content">
# Skip to content</a>
#
#
# <div class="wrapper" id="custom-background-css">
# <header class="mg-headwidget">
# <!--==================== TOP BAR ====================-->
# <div class="mg-head-detail hidden-xs">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-xs-12">
# <ul class="info-left">
# <li>Tue. Feb 9th, 2021             <span class="time" id="time"></span>
# </li>
# </ul>
# </div>
# <div class="col-md-6 col-xs-12">
# <ul class="mg-social info-right">
# <a href="https://www.facebook.com/latestinbollywood1/" target="_blank">
# <li><span class="icon-soci facebook"><i class="fa fa-facebook"></i></span> </li></a>
# <a href="https://twitter.com/latstbollywood" target="_blank">
# <li><span class="icon-soci twitter"><i class="fa fa-twitter"></i></span></li></a>
# <a href="https://www.instagram.com/latestinbollywood/" target="_blank">
# ...
