# %% [markdown]
# <a href="https://colab.research.google.com/github/deepankar-pathak1/100-Day-Code-Challenge/blob/main/KSTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt


x = stats.norm.rvs(size=1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
stats.kstest(x,'norm')
# Out:
# KstestResult(statistic=0.03234173726352341, pvalue=0.24161353522220566)

# %%
y = np.random.uniform(0,1,10000)
sns.kdeplot(np.array(y), bw=0.1)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
stats.kstest(y,'norm')
# Out:
# KstestResult(statistic=0.5000109462710838, pvalue=0.0)
